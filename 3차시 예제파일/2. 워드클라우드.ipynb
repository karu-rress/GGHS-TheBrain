# %% [markdown]
# ## 2. 워드클라우드
#
# [빈칸 및 해설](https://blog.naver.com/nsun527/222800141074)

# %%
# !pip install nltk
# !pip install konlpy
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
from collections import 😊
from konlpy.tag import 😊
from wordcloud import 😊
from PIL import 😊
😊
😊
😊

def flatten(l):
  flatList = []
  for elem in l:
    if type(elem) == list:
      for e in elem:
        flatList.append(e)
    else:
      flatList.append(elem)
  return flatList

# %%
with open(😊, 'r', encoding='UTF-8') as f:
  lines = 😊

hannanum = 😊

temp = []
for i in range(len(lines)):
  temp.append(😊)

word_list = flatten(temp)

stop_words = [😊]

word_list = 😊
word_list = 😊
😊

# %%
wordcloud = WordCloud(
    font_path = 'NanumGothic',
    width = 800,
    height = 800,
    background_color = 'white'
)

count = Counter(word_list)
wordcloud = 😊
array = np.array(😊)

😊
plt.imshow(array, interpolation = 'bilinear')
😊
fig.savefig('wordcloud.png')
