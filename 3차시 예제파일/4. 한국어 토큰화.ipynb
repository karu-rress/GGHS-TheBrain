# %% [markdown]
# ## 4. 한국어 토큰화
#
# [빈칸 및 해설](https://blog.naver.com/nsun527/222802475927)

# %%
# !pip install konlpy

from konlpy.tag import 😊
from konlpy.tag import 😊

# %%
okt = Okt()
kkma = Kkma()

poem = '''
네가 오기로 한 그 자리에
내가 미리 가 너를 기다리는 동안
다가오는 모든 발자국은
내 가슴에 쿵쿵거린다
바스락거리는 나뭇잎 하나도 다 내게 온다
기다려본 적이 있는 사람은 안다
세상에서 기다리는 일처럼 가슴 애리는 일 있을까
네가 오기로 한 그 자리, 내가 미리 와 있는 이곳에서
'''

print('OKT 형태소 분석 :', 😊)
print('OKT 품사 태깅 :', 😊)
print('OKT 명사 추출 :', 😊)

# 동사 추출하기
verbs = [😊]
print('\nOKT 동사 추출 :', verbs)

print('\n꼬꼬마 형태소 분석 :', 😊)
print('꼬꼬마 품사 태깅 :', 😊)
print('꼬꼬마 명사 추출 :', 😊)

# 동사 추출하기
verbs = [😊]
print('\n꼬꼬마 동사 (어간) 추출 :', verbs)

# %%
okt = Okt()

rowdata = "오늘은 날씨가 너무 더운데 이렇게 더운 날이 지속된다면 우리는 모두 타 죽고 말거야"
stop_words = "은 가 너무 더운데 이렇게 더운 이 된다면 는 모두 타 말거야"
stop_words = 😊 # 불용어 셋 준비

word_tokens = okt.morphs(rowdata)
data = [😊]

print('불용어 제거 전 :', word_tokens) 
print('불용어 제거 후 :', data)
